# %%
import tensorflow as tf

from tensorflow.keras import layers
from tensorflow.keras import regularizers

print(tf.__version__)
# Out:
# 2.1.0

# %%
import tensorflow_docs as tfdocs
import tensorflow_docs.modeling
import tensorflow_docs.plots

# %%
from IPython import display
from matplotlib import pyplot as plt

import numpy as np

import pathlib
import shutil
import tempfile

# %%
logdir = pathlib.Path(tempfile.mkdtemp())/"tensorboard_logs"
shutil.rmtree(logdir, ignore_errors=True)

# %%
gz = tf.keras.utils.get_file('HIGGS.csv.gz', 'http://mlphysics.ics.uci.edu/data/higgs/HIGGS.csv.gz')
# Out:
# Downloading data from http://mlphysics.ics.uci.edu/data/higgs/HIGGS.csv.gz
# 2816409600/2816407858 [==============================] - 432s 0us/step

# %%
FEATURES = 28

# %%
ds = tf.data.experimental.CsvDataset(gz,[float(),]*(FEATURES+1), compression_type="GZIP")

# %%
def pack_row(*row):
  label = row[0]
  features = tf.stack(row[1:],1)
  return features, label

# %%
packed_ds = ds.batch(10000).map(pack_row).unbatch()
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function pack_row at 0x0000029058D7DB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING: AutoGraph could not transform <function pack_row at 0x0000029058D7DB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'

# %%
for features,label in packed_ds.batch(1000).take(1):
  print(features[0])
  plt.hist(features.numpy().flatten(), bins = 101)
# Out:
# tf.Tensor(
# [ 0.8692932  -0.6350818   0.22569026  0.32747006 -0.6899932   0.75420225
#  -0.24857314 -1.0920639   0.          1.3749921  -0.6536742   0.9303491
#   1.1074361   1.1389043  -1.5781983  -1.0469854   0.          0.65792954
#  -0.01045457 -0.04576717  3.1019614   1.35376     0.9795631   0.97807616
#   0.92000484  0.72165745  0.98875093  0.87667835], shape=(28,), dtype=float32)

# %%
N_VALIDATION = int(1e3)
N_TRAIN = int(1e4)
BUFFER_SIZE = int(1e4)
BATCH_SIZE = 500
STEPS_PER_EPOCH = N_TRAIN //BATCH_SIZE

# %%
validate_ds = packed_ds.take(N_VALIDATION).cache()
train_ds = packed_ds.skip(N_VALIDATION).take(N_TRAIN).cache()

# %%
train_ds
# Out:
# <CacheDataset shapes: ((28,), ()), types: (tf.float32, tf.float32)>

# %%
validate_ds = validate_ds.batch(BATCH_SIZE)
train_ds = train_ds.shuffle(BUFFER_SIZE).repeat().batch(BATCH_SIZE)

# %%
lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
    0.001,
    decay_steps=STEPS_PER_EPOCH*1000,
    decay_rate=1,
    staircase=False,
    )
def get_optimizer():
    return tf.keras.optimizers.Adam(lr_schedule)

# %%
step = np.linspace(0,100000)
lr = lr_schedule(step)
plt.figure(figsize = (8,6))
plt.plot(step/STEPS_PER_EPOCH, lr)
plt.ylim([0,max(plt.ylim())])
plt.xlabel('Epoch')
_ = plt.ylabel('Learning Rate')

# %%
def get_callbacks(name):
  return [
    tfdocs.modeling.EpochDots(),
    tf.keras.callbacks.EarlyStopping(monitor='val_binary_crossentropy', patience=200),
    tf.keras.callbacks.TensorBoard(logdir/name),
  ]

# %%
def compile_and_fit(model, name, optimizer=None, max_epochs=10000):
  if optimizer is None:
    optimizer = get_optimizer()
  model.compile(optimizer=optimizer,
                loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                metrics=[
                  tf.keras.losses.BinaryCrossentropy(
                      from_logits=True, name='binary_crossentropy'),
                  'accuracy'])

  model.summary()

  history = model.fit(
    train_ds,
    steps_per_epoch = STEPS_PER_EPOCH,
    epochs=max_epochs,
    validation_data=validate_ds,
    callbacks=get_callbacks(name),
    verbose=0)
  return history

# %%
# modelo mini

tiny_model = tf.keras.Sequential([
    layers.Dense(16, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(1)
])

# %%
size_histories = {}

# %%
size_histories['Tiny'] = compile_and_fit(tiny_model, 'sizes/Tiny')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                464
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 481
# Trainable params: 481
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4915,  binary_crossentropy:0.7349,  loss:0.7349,  val_accuracy:0.4780,  val_binary_crossentropy:0.7095,  val_loss:0.7095,
# ....................................................................................................
# Epoch: 100, accuracy:0.5982,  binary_crossentropy:0.6253,  loss:0.6253,  val_accuracy:0.5870,  val_binary_crossentropy:0.6214,  val_loss:0.6214,
# ....................................................................................................
# Epoch: 200, accuracy:0.6327,  binary_crossentropy:0.6099,  loss:0.6099,  val_accuracy:0.6080,  val_binary_crossentropy:0.6042,  val_loss:0.6042,
# ....................................................................................................
# Epoch: 300, accuracy:0.6458,  binary_crossentropy:0.5991,  loss:0.5991,  val_accuracy:0.6470,  val_binary_crossentropy:0.5948,  val_loss:0.5948,
# ....................................................................................................
# Epoch: 400, accuracy:0.6625,  binary_crossentropy:0.5916,  loss:0.5916,  val_accuracy:0.6330,  val_binary_crossentropy:0.5916,  val_loss:0.5916,
# ....................................................................................................
# Epoch: 500, accuracy:0.6667,  binary_crossentropy:0.5858,  loss:0.5858,  val_accuracy:0.6650,  val_binary_crossentropy:0.5878,  val_loss:0.5878,
# ....................................................................................................
# Epoch: 600, accuracy:0.6756,  binary_crossentropy:0.5821,  loss:0.5821,  val_accuracy:0.6500,  val_binary_crossentropy:0.5899,  val_loss:0.5899,
# ....................................................................................................
# Epoch: 700, accuracy:0.6751,  binary_crossentropy:0.5794,  loss:0.5794,  val_accuracy:0.6760,  val_binary_crossentropy:0.5882,  val_loss:0.5882,
# ............................................................

# %%
plotter = tfdocs.plots.HistoryPlotter(metric = 'binary_crossentropy', smoothing_std=10)
plotter.plot(size_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
small_model = tf.keras.Sequential([
    layers.Dense(16, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(16, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(1)
])

# %%
size_histories['Small'] = compile_and_fit(small_model, 'sizes/Small')
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 110
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 16)                464
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 753
# Trainable params: 753
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5073,  binary_crossentropy:0.7448,  loss:0.7448,  val_accuracy:0.4960,  val_binary_crossentropy:0.7025,  val_loss:0.7025,
# ....................................................................................................
# Epoch: 100, accuracy:0.6307,  binary_crossentropy:0.6097,  loss:0.6097,  val_accuracy:0.6260,  val_binary_crossentropy:0.6045,  val_loss:0.6045,
# ....................................................................................................
# Epoch: 200, accuracy:0.6695,  binary_crossentropy:0.5883,  loss:0.5883,  val_accuracy:0.6480,  val_binary_crossentropy:0.5855,  val_loss:0.5855,
# ....................................................................................................
# Epoch: 300, accuracy:0.6744,  binary_crossentropy:0.5799,  loss:0.5799,  val_accuracy:0.6840,  val_binary_crossentropy:0.5827,  val_loss:0.5827,
# ....................................................................................................
# Epoch: 400, accuracy:0.6781,  binary_crossentropy:0.5753,  loss:0.5753,  val_accuracy:0.6770,  val_binary_crossentropy:0.5820,  val_loss:0.5820,
# ....................................................................................................
# Epoch: 500, accuracy:0.6795,  binary_crossentropy:0.5711,  loss:0.5711,  val_accuracy:0.6740,  val_binary_crossentropy:0.5837,  val_loss:0.5837,
# ....................................................................................................
# Epoch: 600, accuracy:0.6889,  binary_crossentropy:0.5655,  loss:0.5655,  val_accuracy:0.6780,  val_binary_crossentropy:0.5838,  val_loss:0.5838,
# ....................................................................................................
# Epoch: 700, accuracy:0.6910,  binary_crossentropy:0.5609,  loss:0.5609,  val_accuracy:0.6930,  val_binary_crossentropy:0.5817,  val_loss:0.5817,
# ....................................................................

# %%
medium_model = tf.keras.Sequential([
    layers.Dense(64, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(64, activation='elu'),
    layers.Dense(64, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['Medium']  = compile_and_fit(medium_model, "sizes/Medium")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 64)                1856
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 10,241
# Trainable params: 10,241
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5014,  binary_crossentropy:0.6914,  loss:0.6914,  val_accuracy:0.4910,  val_binary_crossentropy:0.6795,  val_loss:0.6795,
# ....................................................................................................
# Epoch: 100, accuracy:0.7106,  binary_crossentropy:0.5326,  loss:0.5326,  val_accuracy:0.6410,  val_binary_crossentropy:0.6206,  val_loss:0.6206,
# ....................................................................................................
# Epoch: 200, accuracy:0.7788,  binary_crossentropy:0.4440,  loss:0.4440,  val_accuracy:0.6130,  val_binary_crossentropy:0.7175,  val_loss:0.7175,
# ............................................................

# %%
large_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(512, activation='elu'),
    layers.Dense(512, activation='elu'),
    layers.Dense(512, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['large'] = compile_and_fit(large_model, "sizes/large")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 512)               14848
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_11 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5009,  binary_crossentropy:0.7917,  loss:0.7917,  val_accuracy:0.5160,  val_binary_crossentropy:0.6743,  val_loss:0.6743,
# ....................................................................................................
# Epoch: 100, accuracy:1.0000,  binary_crossentropy:0.0021,  loss:0.0021,  val_accuracy:0.6550,  val_binary_crossentropy:1.7447,  val_loss:1.7447,
# ....................................................................................................
# Epoch: 200, accuracy:1.0000,  binary_crossentropy:0.0001,  loss:0.0001,  val_accuracy:0.6580,  val_binary_crossentropy:2.3633,  val_loss:2.3633,
# ........................

# %%
plotter.plot(size_histories)
a = plt.xscale('log')
plt.xlim([5, max(plt.xlim())])
plt.ylim([0.5, 0.7])
plt.xlabel("Epochs [Log Scale]")
# Out:
# Text(0.5, 0, 'Epochs [Log Scale]')

# %%
# %load_ext tensorboard

# %tensorboard --logdir {logdir}/sizes
# Out:
# ERROR: Failed to launch TensorBoard (exited with 1).
# Contents of stderr:
# 2021-11-27 20:49:24.468321: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_101.dll
# Traceback (most recent call last):
#   File "C:\Users\zlope\miniconda3\envs\tensorflow\Scripts\tensorboard-script.py", line 5, in <module>
#     from tensorboard.main import run_main
#   File "C:\Users\zlope\miniconda3\envs\tensorflow\lib\site-packages\tensorboard\main.py", line 43, in <module>
#     from tensorboard import default
#   File "C:\Users\zlope\miniconda3\envs\tensorflow\lib\site-packages\tensorboard\default.py", line 40, in <module>
#     from tensorboard.plugins.beholder import beholder_plugin_loader
#   File "C:\Users\zlope\miniconda3\envs\tensorflow\lib\site-packages\tensorboard\plugins\beholder\__init__.py", line 22, in <module>
#     from tensorboard.plugins.beholder.beholder import Beholder
#   File "C:\Users\zlope\miniconda3\envs\tensorflow\lib\site-packages\tensorboard\plugins\beholder\beholder.py", line 212, in <module>
#     class BeholderHook(tf.estimator.SessionRunHook):
# AttributeError: module 'tensorflow' has no attribute 'estimator'

# %%
display.IFrame(
    src="https://tensorboard.dev/experiment/vW7jmmF9TmKmy3rbheMQpw/#scalars&_smoothingWeight=0.97",
    width="100%", height="800px")
# Out:
#         <iframe
#             width="100%"
#             height="800px"
#             src="https://tensorboard.dev/experiment/vW7jmmF9TmKmy3rbheMQpw/#scalars&_smoothingWeight=0.97"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
shutil.rmtree(logdir/'regularizers/Tiny', ignore_errors=True)
shutil.copytree(logdir/'sizes/Tiny', logdir/'regularizers/Tiny')
# Out:
# WindowsPath('C:/Users/zlope/AppData/Local/Temp/tmpdtcvp6bi/tensorboard_logs/regularizers/Tiny')

# %%
regularizer_histories = {}
regularizer_histories['Tiny'] = size_histories['Tiny']

# %%
l2_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu',
                kernel_regularizer=regularizers.l2(0.001),
                input_shape=(FEATURES,)),
    layers.Dense(512, activation='elu',
                kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(512, activation='elu',
                kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(512, activation='elu',
                kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(1)
])

regularizer_histories['l2'] = compile_and_fit(l2_model, "regularizers/l2")
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_14 (Dense)             (None, 512)               14848
# _________________________________________________________________
# dense_15 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_16 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_17 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5066,  binary_crossentropy:0.8152,  loss:2.3383,  val_accuracy:0.4900,  val_binary_crossentropy:0.6887,  val_loss:2.1347,
# ....................................................................................................
# Epoch: 100, accuracy:0.6563,  binary_crossentropy:0.5960,  loss:0.6201,  val_accuracy:0.6490,  val_binary_crossentropy:0.5826,  val_loss:0.6066,
# ....................................................................................................
# Epoch: 200, accuracy:0.6725,  binary_crossentropy:0.5832,  loss:0.6059,  val_accuracy:0.6500,  val_binary_crossentropy:0.5834,  val_loss:0.6063,
# ....................................................................................................
# Epoch: 300, accuracy:0.6755,  binary_crossentropy:0.5752,  loss:0.5980,  val_accuracy:0.7020,  val_binary_crossentropy:0.5823,  val_loss:0.6051,
# ....................................................................................................
# Epoch: 400, accuracy:0.6880,  binary_crossentropy:0.5690,  loss:0.5916,  val_accuracy:0.6770,  val_binary_crossentropy:0.5818,  val_loss:0.6043,
# .................

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
result = l2_model(features)
regularization_loss=tf.add_n(l2_model.losses)

# %%
dropout_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu', input_shape=(FEATURES,)),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(1)
])

regularizer_histories['dropout'] = compile_and_fit(dropout_model, "regularizers/dropout")
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 512)               14848
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5087,  binary_crossentropy:0.8026,  loss:0.8026,  val_accuracy:0.5210,  val_binary_crossentropy:0.6793,  val_loss:0.6793,
# ....................................................................................................
# Epoch: 100, accuracy:0.6546,  binary_crossentropy:0.5966,  loss:0.5966,  val_accuracy:0.6670,  val_binary_crossentropy:0.5780,  val_loss:0.5780,
# ....................................................................................................
# Epoch: 200, accuracy:0.6879,  binary_crossentropy:0.5578,  loss:0.5578,  val_accuracy:0.6800,  val_binary_crossentropy:0.5803,  val_loss:0.5803,
# ....................................................................................................
# Epoch: 300, accuracy:0.7165,  binary_crossentropy:0.5175,  loss:0.5175,  val_accuracy:0.6830,  val_binary_crossentropy:0.5907,  val_loss:0.5907,
# ...........

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
combined_model = tf.keras.Sequential([
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu', input_shape=(FEATURES,)),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(1)
])

regularizer_histories['combined'] = compile_and_fit(combined_model, "regularizers/combined")
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             (None, 512)               14848
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5155,  binary_crossentropy:0.7878,  loss:0.9461,  val_accuracy:0.4890,  val_binary_crossentropy:0.6756,  val_loss:0.8332,
# ....................................................................................................
# Epoch: 100, accuracy:0.6475,  binary_crossentropy:0.6048,  loss:0.6347,  val_accuracy:0.6640,  val_binary_crossentropy:0.5810,  val_loss:0.6108,
# ....................................................................................................
# Epoch: 200, accuracy:0.6653,  binary_crossentropy:0.5883,  loss:0.6144,  val_accuracy:0.6620,  val_binary_crossentropy:0.5771,  val_loss:0.6032,
# ....................................................................................................
# Epoch: 300, accuracy:0.6683,  binary_crossentropy:0.5829,  loss:0.6115,  val_accuracy:0.6630,  val_binary_crossentropy:0.5715,  val_loss:0.6003,
# ....................................................................................................
# Epoch: 400, accuracy:0.6727,  binary_crossentropy:0.5765,  loss:0.6067,  val_accuracy:0.6940,  val_binary_crossentropy:0.5526,  val_loss:0.5828,
# ....................................................................................................
# Epoch: 500, accuracy:0.6787,  binary_crossentropy:0.5722,  loss:0.6044,  val_accuracy:0.6790,  val_binary_crossentropy:0.5604,  val_loss:0.5925,
# ....................................................................................................
# Epoch: 600, accuracy:0.6829,  binary_crossentropy:0.5698,  loss:0.6041,  val_accuracy:0.6980,  val_binary_crossentropy:0.5454,  val_loss:0.5797,
# ....................................................................................................
# Epoch: 700, accuracy:0.6837,  binary_crossentropy:0.5644,  loss:0.6006,  val_accuracy:0.7030,  val_binary_crossentropy:0.5431,  val_loss:0.5792,
# ....................................................................................................
# Epoch: 800, accuracy:0.6886,  binary_crossentropy:0.5574,  loss:0.5953,  val_accuracy:0.6890,  val_binary_crossentropy:0.5454,  val_loss:0.5832,
# ....................................................................................................
# Epoch: 900, accuracy:0.6933,  binary_crossentropy:0.5527,  loss:0.5920,  val_accuracy:0.6990,  val_binary_crossentropy:0.5447,  val_loss:0.5840,
# ....................................................................................................
# Epoch: 1000, accuracy:0.6938,  binary_crossentropy:0.5519,  loss:0.5925,  val_accuracy:0.6950,  val_binary_crossentropy:0.5465,  val_loss:0.5871,
# ....................................

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
# %tensorboard --logdir {logdir}/regularizers
# Out:
# ERROR: Failed to launch TensorBoard (exited with 1).
# Contents of stderr:
# 2021-11-27 21:18:09.735037: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_101.dll
# Traceback (most recent call last):
#   File "C:\Users\zlope\miniconda3\envs\tensorflow\Scripts\tensorboard-script.py", line 5, in <module>
#     from tensorboard.main import run_main
#   File "C:\Users\zlope\miniconda3\envs\tensorflow\lib\site-packages\tensorboard\main.py", line 43, in <module>
#     from tensorboard import default
#   File "C:\Users\zlope\miniconda3\envs\tensorflow\lib\site-packages\tensorboard\default.py", line 40, in <module>
#     from tensorboard.plugins.beholder import beholder_plugin_loader
#   File "C:\Users\zlope\miniconda3\envs\tensorflow\lib\site-packages\tensorboard\plugins\beholder\__init__.py", line 22, in <module>
#     from tensorboard.plugins.beholder.beholder import Beholder
#   File "C:\Users\zlope\miniconda3\envs\tensorflow\lib\site-packages\tensorboard\plugins\beholder\beholder.py", line 212, in <module>
#     class BeholderHook(tf.estimator.SessionRunHook):
# AttributeError: module 'tensorflow' has no attribute 'estimator'

# %%
display.IFrame(
    src="https://tensorboard.dev/experiment/fGInKDo8TXes1z7HQku9mw/#scalars&_smoothingWeight=0.97",
    width = "100%",
    height="800px")
# Out:
#         <iframe
#             width="100%"
#             height="800px"
#             src="https://tensorboard.dev/experiment/fGInKDo8TXes1z7HQku9mw/#scalars&_smoothingWeight=0.97"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
